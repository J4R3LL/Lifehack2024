# %%
import articles_jarell as cna

cna_articles = cna.cna_articles()

# %%
import spacy
import networkx as nx
nlp = spacy.load("en_core_web_sm")

def extract_entities(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    entities = []
    for entity in doc.ents:
        entities.append(entity.text)
    return entities

def extract_relationships(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    relationships = []
    for token in doc:
        if token.dep_ in ["prep", "pobj"]:  # Extract prepositional phrases and their objects
            relationships.append((token.head.text, token.text))
    return relationships

def create_knowledge_graph(text):
    entities = extract_entities(text)
    relationships = extract_relationships(text)
    G = nx.Graph()
    G.add_nodes_from(entities)
    G.add_edges_from(relationships)
    return G

text = ''.join(cna_articles)
knowledge_graph = create_knowledge_graph(text)
print("Nodes:", knowledge_graph.nodes())
print("Edges:", knowledge_graph.edges())
# Out:
# Nodes: ['SINGAPORE', 'American', 'Paul Nicholas Miller', '16', 'Singaporean', 'Chinese', '4', 'Internal Security Department', 'ISD', 'Wednesday', 'Jan 24).This', 'second', 'Mustaffa', 'Ms Munira', 'Chasseur Group', 'Islamophobia', '16-year-old', 'the Great Replacement Theory', 'Christchurch', 'Brenton Tarrant', 'first', 'Indian', 'Bilveer Singh', 'Christianity', 'Islam', 'the National University of Singapore', 'Tarrants', 'Kumar Ramakrishnan', 'the S. Rajaratnam School of International Studies', 'Asia', 'decades', 'Tarrant', 'Shashi Jayakumar', 'one', 'Jolene Jerard', 'atpublic safety and management', 'Centinel', 'Singapore', 'Dr Jerard', 'Earlier this month', 'Scoot', 'Perth', 'Australian', 'Last year', 'Singapore Airlines', 'San Francisco', 'more than 12 hours', 'Changi Airport', 'The Republic of Singapore Air Forces', 'more than 350', 'each year', '2022', 'the Singapore Armed Forces PIONEER', 'thousands of feet', 'CNA', 'Jeffrey Charles Price', 'the Metropolitan State University of Denver', 'RSAF', 'two', 'minutes', '36thBattalion', 'PIONEER', 'the South China Sea', 'Malaysia', 'about 50 minutes', 'Prof Price', '911', 'three hours', 'the SAFs Chemical, Biological, Radiological and Explosive Defence Group', 'the Airport Police Division', 'the Internal Security Department', 'Monday', 'annual', 'three', 'the past year', 'One', 'Islamic', 'Roblox', 'November 2022', 'Ismail Menk', 'ISA', '2015', '11', 'Singaporeans', '20', 'five', 'United Nations', 'February', 'Islamic State orISIS', 'the Islamic State', 'Iraq', 'Syria),Al-Qaeda', 'Syria', 'ISD.It', 'ISIS', 'Southeast Asia', 'Muslims', 'Asian', 'JI', '2019', 'Indonesian', 'the Indonesian General Elections', '2024.ISD', 'Russia', 'the Middle East', 'third', 'Lawrence Wong', 'theReligious Rehabilitation Groups', 'RRG', '18th', 'Wong', '2003', 'Jemaah Islamiyah', 'Islamic State of Iraq', 'Al-Qaeda', 'a matter of months', 'weeks', '15-year-old', 'the Internal Security Act', 'ISA).Mr Wong', 'January', 'State', 'the ISD (Internal Security Department', '21', '14 years old', 'Protestant Christian', 'Two', 'theInternal Security Act', 'Tuesday', '3', 'Tuesdays', 'December 2020.The', 'non-Muslims', 'early last year', 'Zimbabwean Salafi', 'mid-2022', 'Shia', 'Sufi Muslims', 'Syariah', 'Afghanistan', 'Shia Muslims', 'Yazidis', 'August 2014', 'Yazidi', 'Iraqi', 'Sinjar', 'about 3,100', 'the first month', 'the latter half', 'bin Laden', 'Americans', 'November 2020', 'anti-Semitic', 'Nazi', 'YouTube', 'Marawi', 'Philippines', 'between late 2021', '18-year-old', 'December 2022.While', 'Irfan', 'RO', 'theReligious Rehabilitation GroupsResource', 'Counselling Centre', 'Mohamed Ali', 'the Religious Rehabilitation Group', 'today', 'Dr Mohamed', 'Mohamed', 'Muhammad Irfan Danyal Mohamad', 'Feb 1).Irfan', 'December', 'Home Affairs', 'Law Minister K Shanmugam', '2020', 'Zakir Naik', '2014.He', 'Islamic State', 'Aug 9 last year - Singapore', 'National Day - Irfan', 'Coney Island', 'Hayat Tahrir al-Sham', 'the “Islamic State of Singhafura”', 'the same day', 'October', 'Tan Si Hui', 'August last year', 'Amoy Quee Camp', 'Ang Mo Kio', 'the National Cadet Corps', 'the Singapore Armed Forces', 'SAF', 'MINDEF', 'Keramat Habib Noh', 'Haji Muhammad Salleh Mosque', 'Amoy Quee', 'Irfans', 'nine', 'Internal Security Act', '2015.Responding', 'Singaporean Imran Mahmood', '11).One', '63', 'the Jemaah Islamiyah', 'May 2006', 'four', 'Mas Selamat Kastari', 'December 2001', 'Mas Selamat', 'Rashid', 'May 2014', 'May last year', '38-year-old', 'the Ministry of Education', 'October last year', 'Mohamed Khairul Riduan Mohamed Sarip', 'Gaza city', 'MOE', 'Palestine', 'Jan 11).Khairul', 'Amirull Ali', 'February 2021', 'Jews', 'Waterloo Street', 'Gaza', 'HAMAS', 'Israel', 'last October', 'Nov 30 last year', 'Khairul', 'Christians', '2007', 'Israeli', 'Palestinians', 'Israelis', 'the Israel Defence Forces', 'Naik', 'Ahmed Deedat', '2014', '2012', 'Facebook titled Panggilan Jihad', 'Call to Jihad', 'Izz', 'AQB', 'that year', '20 ...
# Edges: [('American', 'of'), ('Singaporean', 'of'), ('Singaporean', 'on'), ('ISD', 'by'), ('ISD', 'to'), ('ISD', 'for'), ('ISD', 'with'), ('ISD', 'in'), ('Wednesday', 'on'), ('Wednesday', 'On'), ('second', 'in'), ('Islamophobia', 'of'), ('Christchurch', 'in'), ('Christianity', 'with'), ('Islam', 'to'), ('Islam', 'of'), ('Islam', 'on'), ('Islam', 'in'), ('Tarrants', 'in'), ('Asia', 'in'), ('Asia', 'In'), ('Asia', 'Within'), ('Asia', 'from'), ('Asia', 'including'), ('decades', 'for'), ('decades', 'from'), ('Tarrant', 'like'), ('Tarrant', 'by'), ('one', 'of'), ('one', 'as'), ('one', 'on'), ('one', 'after'), ('one', 'with'), ('one', 'including'), ('one', 'to'), ('Singapore', 'of'), ('Singapore', 'In'), ('Singapore', 'to'), ('Singapore', 'in'), ('Singapore', 'on'), ('Singapore', 'like'), ('Singapore', 'into'), ('Singapore', 'against'), ('Singapore', 'Within'), ('Singapore', 'from'), ('Singapore', 'for'), ('Singapore', 'over'), ('Singapore', 'with'), ('2022', 'since'), ('2022', 'in'), ('CNA', 'from'), ('two', 'to'), ('two', 'of'), ('minutes', 'for'), ('minutes', 'to'), ('36thBattalion', 'from'), ('36thBattalion', 'of'), ('PIONEER', 'in'), ('Malaysia', 'of'), ('Malaysia', 'to'), ('Malaysia', 'in'), ('911', 'after'), ('911', 'of'), ('Monday', 'on'), ('Monday', 'from'), ('One', 'of'), ('Roblox', 'on'), ('Roblox', 'in'), ('Roblox', 'as'), ('ISA', 'under'), ('2015', 'Since'), ('2015', 'Before'), ('2015', 'since'), ('2015', 'at'), ('Singaporeans', 'of'), ('Singaporeans', 'to'), ('Singaporeans', 'against'), ('Singaporeans', 'in'), ('20', 'with'), ('20', 'in'), ('five', 'of'), ('February', 'in'), ('February', 'between'), ('February', 'Between'), ('Iraq', 'in'), ('Iraq', 'like'), ('Iraq', 'of'), ('Syria', 'to'), ('Syria', 'in'), ('ISIS', 'like'), ('ISIS', 'by'), ('ISIS', 'with'), ('ISIS', 'for'), ('ISIS', 'in'), ('ISIS', 'of'), ('ISIS', 'IN'), ('Muslims', 'against'), ('Muslims', 'of'), ('Muslims', 'on'), ('Muslims', 'in'), ('Muslims', 'around'), ('JI', 'like'), ('JI', 'of'), ('2019', 'in'), ('2019', 'In'), ('2024.ISD', 'in'), ('RRG', 'of'), ('RRG', 'onboard'), ('2003', 'in'), ('January', 'in'), ('January', 'In'), ('State', 'in'), ('State', 'of'), ('State', 'for'), ('State', 'by'), ('State', 'alongside'), ('State', 'like'), ('State', 'as'), ('State', 'including'), ('State', 'with'), ('State', 'to'), ('State', 'about'), ('State', 'against'), ('State', 'on'), ('21', 'below'), ('Tuesday', 'on'), ('mid-2022', 'By'), ('Syariah', 'by'), ('Afghanistan', 'to'), ('Afghanistan', 'in'), ('Afghanistan', 'from'), ('Afghanistan', 'including'), ('Sinjar', 'of'), ('Americans', 'against'), ('Marawi', 'of'), ('Marawi', 'in'), ('Philippines', 'in'), ('Philippines', 'from'), ('Philippines', 'with'), ('Irfan', 'on'), ('December', 'in'), ('December', 'to'), ('2020', 'in'), ('October', 'By'), ('October', 'in'), ('October', 'from'), ('October', 'since'), ('2015.Responding', 'since'), ('2015.Responding', 'to'), ('11).One', 'of'), ('Palestine', 'to'), ('Palestine', 'in'), ('Jews', 'against'), ('Gaza', 'of'), ('Gaza', 'in'), ('Gaza', 'to'), ('HAMAS', 'with'), ('HAMAS', 'into'), ('HAMAS', 'by'), ('HAMAS', 'to'), ('HAMAS', 'for'), ('HAMAS', 'alongside'), ('Israel', 'against'), ('Israel', 'in'), ('2007', 'in'), ('Palestinians', 'against'), ('Palestinians', 'including'), ('Palestinians', 'of'), ('Naik', 'as'), ('Naik', 'by'), ('2014', 'since'), ('2014', 'in'), ('2014', 'In'), ('2014', 'to'), ('2012', 'in'), ('2021', 'between'), ('2021', 'in'), ('COVID-19', 'of'), ('COVID-19', 'to'), ('2021.ISD', 'in'), ('ICA', 'at'), ('RSIS', 'of'), ('Indonesia', 'in'), ('Friday', 'on'), ('2022.In', 'in'), ('Taliban', 'between'), ('Taliban', 'with'), ('Istanbul', 'in'), ('Sunday', 'on'), ('Ankara', 'in'), ('Turkey', 'in'), ('Turkey', 'to'), ('US', 'in'), ('US', 'like'), ('Islamists', 'with'), ('mosques', 'at'), ('mosques', 'in'), ('2019.“Globally', 'in'), ('Ukraine', 'in'), ('Crimea', 'of'), ('April', 'in'), ('April', 'In'), ('Radjev', 'of'), ('Radjev', 'with'), ('2013', 'in'), ('2013', 'to ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Function to enhance input with knowledge graph
def enhance_input_with_kg(input_text):
    # Extract entities from the input text
    doc = nlp(input_text)
    entities = [ent.text for ent in doc.ents]
    
    # Append knowledge graph information to the input text
    enhanced_text = input_text
    for entity in entities:
        if entity in knowledge_graph:
            facts = " ".join(knowledge_graph[entity])
            enhanced_text += f" {entity} {facts}."
    
    return enhanced_text

# Load the LLaMA2 model and tokenizer
model_name = "meta-llama/Meta-Llama-3-8B"  # Replace with the actual model name
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# User input
user_input = input("user: ")
enhanced_input = enhance_input_with_kg(user_input)

# Tokenize and generate response
input_tokens = tokenizer.encode(enhanced_input, return_tensors="pt")
output = model.generate(input_tokens, max_length=100, num_return_sequences=1)

# Decode and print the response
response = tokenizer.decode(output[0], skip_special_tokens=True)
print("LLM:", response)
# Out:
# c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\utils\_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Meta-Llama-3-8B/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\transformers\utils\hub.py:399, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     397 try:
#     398     # Load from URL or cache if already cached
# --> 399     resolved_file = hf_hub_download(
#     400         path_or_repo_id,
#     401         filename,
#     402         subfolder=None if len(subfolder) == 0 else subfolder,
#     403         repo_type=repo_type,
#     404         revision=revision,
#     405         cache_dir=cache_dir,
#     406         user_agent=user_agent,
#     407         force_download=force_download,
#     408         proxies=proxies,
#     409         resume_download=resume_download,
#     410         token=token,
#     411         local_files_only=local_files_only,
#     412     )
#     413 except GatedRepoError as e:
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\file_download.py:1221, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1220 else:
# -> 1221     return _hf_hub_download_to_cache_dir(
#    1222         # Destination
#    1223         cache_dir=cache_dir,
#    1224         # File info
#    1225         repo_id=repo_id,
#    1226         filename=filename,
#    1227         repo_type=repo_type,
#    1228         revision=revision,
#    1229         # HTTP info
#    1230         headers=headers,
#    1231         proxies=proxies,
#    1232         etag_timeout=etag_timeout,
#    1233         endpoint=endpoint,
#    1234         # Additional options
#    1235         local_files_only=local_files_only,
#    1236         force_download=force_download,
#    1237     )
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\file_download.py:1325, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, headers, proxies, etag_timeout, endpoint, local_files_only, force_download)
#    1324     # Otherwise, raise appropriate error
# -> 1325     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1327 # From now on, etag, commit_hash, url and size are not None.
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\file_download.py:1823, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1821 elif isinstance(head_call_error, RepositoryNotFoundError) or isinstance(head_call_error, GatedRepoError):
#    1822     # Repo not found or gated => let's raise the actual error
# -> 1823     raise head_call_error
#    1824 else:
#    1825     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\file_download.py:1722, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, local_files_only, relative_filename, storage_folder)
#    1721 try:
# -> 1722     metadata = get_hf_file_metadata(url=url, proxies=proxies, timeout=etag_timeout, headers=headers)
#    1723 except EntryNotFoundError as http_error:
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\file_download.py:1645, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1644 # Retrieve metadata
# -> 1645 r = _request_wrapper(
#    1646     method="HEAD",
#    1647     url=url,
#    1648     headers=headers,
#    1649     allow_redirects=False,
#    1650     follow_relative_redirects=True,
#    1651     proxies=proxies,
#    1652     timeout=timeout,
#    1653 )
#    1654 hf_raise_for_status(r)
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\file_download.py:372, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     371 if follow_relative_redirects:
# --> 372     response = _request_wrapper(
#     373         method=method,
#     374         url=url,
#     375         follow_relative_redirects=False,
#     376         **params,
#     377     )
#     379     # If redirection, we redirect only relative paths.
#     380     # This is useful in case of a renamed repository.
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\file_download.py:396, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     395 response = get_session().request(method=method, url=url, **params)
# --> 396 hf_raise_for_status(response)
#     397 return response
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\huggingface_hub\utils\_errors.py:321, in hf_raise_for_status(response, endpoint_name)
#     318     message = (
#     319         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     320     )
# --> 321     raise GatedRepoError(message, response) from e
#     323 elif error_message == "Access to this resource is disabled.":
#
# GatedRepoError: 401 Client Error. (Request ID: Root=1-665a3196-3e5b66595ffaa01922cf64a4;2d4a8051-383b-4bda-a5f5-f30e80d7da8c)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Meta-Llama-3-8B/resolve/main/config.json.
# Access to model meta-llama/Meta-Llama-3-8B is restricted. You must be authenticated to access it.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 20
#      18 # Load the LLaMA2 model and tokenizer
#      19 model_name = "meta-llama/Meta-Llama-3-8B"  # Replace with the actual model name
# ---> 20 tokenizer = AutoTokenizer.from_pretrained(model_name)
#      21 model = AutoModelForCausalLM.from_pretrained(model_name)
#      23 # User input
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\transformers\models\auto\tokenization_auto.py:837, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     835         config = AutoConfig.for_model(**config_dict)
#     836     else:
# --> 837         config = AutoConfig.from_pretrained(
#     838             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     839         )
#     840 config_tokenizer_class = config.tokenizer_class
#     841 if hasattr(config, "auto_map") and "AutoTokenizer" in config.auto_map:
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\transformers\models\auto\configuration_auto.py:934, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     931 trust_remote_code = kwargs.pop("trust_remote_code", None)
#     932 code_revision = kwargs.pop("code_revision", None)
# --> 934 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     935 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#     936 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\transformers\configuration_utils.py:632, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     630 original_kwargs = copy.deepcopy(kwargs)
#     631 # Get config dict associated with the base config file
# --> 632 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     633 if "_commit_hash" in config_dict:
#     634     original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\transformers\configuration_utils.py:689, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     685 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     687 try:
#     688     # Load from local folder or from cache or download from model Hub and cache
# --> 689     resolved_config_file = cached_file(
#     690         pretrained_model_name_or_path,
#     691         configuration_file,
#     692         cache_dir=cache_dir,
#     693         force_download=force_download,
#     694         proxies=proxies,
#     695         resume_download=resume_download,
#     696         local_files_only=local_files_only,
#     697         token=token,
#     698         user_agent=user_agent,
#     699         revision=revision,
#     700         subfolder=subfolder,
#     701         _commit_hash=commit_hash,
#     702     )
#     703     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     704 except EnvironmentError:
#     705     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted to
#     706     # the original exception.
#
# File c:\Users\Jarell\Downloads\lifehack\Lifehack2024\.conda\Lib\site-packages\transformers\utils\hub.py:417, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     415     if resolved_file is not None or not _raise_exceptions_for_gated_repo:
#     416         return resolved_file
# --> 417     raise EnvironmentError(
#     418         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     419         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     420     ) from e
#     421 except RepositoryNotFoundError as e:
#     422     raise EnvironmentError(
#     423         f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     424         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to pass a token "
#     425         "having permission to this repo either by logging in with `huggingface-cli login` or by passing "
#     426         "`token=<your_token>`"
#     427     ) from e
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Meta-Llama-3-8B.
# 401 Client Error. (Request ID: Root=1-665a3196-3e5b66595ffaa01922cf64a4;2d4a8051-383b-4bda-a5f5-f30e80d7da8c)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Meta-Llama-3-8B/resolve/main/config.json.
# Access to model meta-llama/Meta-Llama-3-8B is restricted. You must be authenticated to access it.
